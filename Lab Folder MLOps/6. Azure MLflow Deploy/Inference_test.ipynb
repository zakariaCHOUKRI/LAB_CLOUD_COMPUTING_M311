# %%
import requests

import json

import pandas as pd

# %%
local_deployment = True
scoring_uri = 'http://90c8c877-f006-4c6a-8bdd-97fe0b1fefda.francecentral.azurecontainer.io/score'
api_key = None
input_path = 'diabetes.csv'# load the data for testing
df = pd.read_csv(input_path, sep = ',')
y = df.pop('Outcome')
X = df
input_data = json.dumps({'input':X.head(1).to_json(orient = 'records')})
print(input_data)
if local_deployment:
    headers = {'Content-Type':'application/json'}
else:
    headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}
resp = requests.post(scoring_uri, input_data, headers=headers)
print("prediction:", resp.text)
# Out:
# {"input": "[{\"Pregnancies\":6,\"Glucose\":148,\"BloodPressure\":72,\"SkinThickness\":35,\"Insulin\":0,\"BMI\":33.6,\"DiabetesPedigreeFunction\":0.627,\"Age\":50}]"}
# prediction: "{\"proba\": [0.7576835983265137]}"
